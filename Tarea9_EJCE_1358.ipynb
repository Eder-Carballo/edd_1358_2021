# %% [markdown]
# <a href="https://colab.research.google.com/github/Eder-Carballo/edd_1358_2021/blob/master/Tarea9_EJCE_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Queue:
    def __init__( self ):
        self.__data = list()

    def is_empty( self ):
        return len(self.__data) == 0

    def length( self ):
        return len(self.__data)

    def enqueue(self , item ):
        self.__data.append( item )

    def dequeue( self ):
        if not self.is_empty():
            return self.__data.pop(0)
        else: 
            return None 

    def to_string( self ):
        cadena = ""
        for elem in self.__data:
            cadena = cadena+"|"+ elem
        cadena = cadena+"|"
        return cadena

# %%
class BoundedPriorityQueue:
    def __init__( self , niveles):
        self.__data = [Queue() for x in range(niveles)]
        self.__size = 0 

    def is_empty( self ):
        return self.__size == 0

    def lenght( self ):
        return self.__size
    
    def enqueue( self, prioridad , elem ):
        if prioridad < len(self.__data) and prioridad >= 0:
            self.__data[prioridad].enqueue(elem)
            self.__size +=1
        else:
            print("Prioridad fuera de rango.")

    def dequeue( self ):
        try:
            if not self.is_empty():
                nivel = 0
                while self.__data[nivel].is_empty():
                    nivel += 1
                return self.__data[nivel].dequeue()
        except IndexError:
            print("No hay nadie en la cola, el barco ya ha sido evacuado por completo.")
            
    def to_string( self ):
        for nivel in range( len(self.__data)):
            print(f" |{nivel}{self.__data[nivel].to_string()}")
        print("")

# %%
cpa = BoundedPriorityQueue( 7 )
print("Abordando el barco")
print("")
cpa.enqueue( 4 , "Maestre")
cpa.to_string()
cpa.enqueue( 2 , "Niños")
cpa.to_string()
cpa.enqueue( 4 , "Mecanico")
cpa.to_string()
cpa.enqueue( 3 , "Mujeres")
cpa.to_string()
cpa.enqueue( 2 , "3ra Edad")
cpa.to_string()
cpa.enqueue( 1 , "Niñas")
cpa.to_string()
cpa.enqueue( 3 , "Hombres")
cpa.to_string()
cpa.enqueue( 4 , "Vigia")
cpa.to_string()
cpa.enqueue( 5 , "Capitan")
cpa.to_string()
cpa.enqueue( 4 , "Timonel")
cpa.to_string()
print("")
print("Abandonando el barco")
print("")
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
# Out:
# Abordando el barco
#
#  |0|
#  |1|
#  |2|
#  |3|
#  |4|Maestre|
#  |5|
#  |6|
#
#  |0|
#  |1|
#  |2|Niños|
#  |3|
#  |4|Maestre|
#  |5|
#  |6|
#
#  |0|
#  |1|
#  |2|Niños|
#  |3|
#  |4|Maestre|Mecanico|
#  |5|
#  |6|
#
#  |0|
#  |1|
#  |2|Niños|
#  |3|Mujeres|
#  |4|Maestre|Mecanico|
#  |5|
#  |6|
#
#  |0|
#  |1|
#  |2|Niños|3ra Edad|
#  |3|Mujeres|
#  |4|Maestre|Mecanico|
#  |5|
#  |6|
#
#  |0|
#  |1|Niñas|
#  |2|Niños|3ra Edad|
#  |3|Mujeres|
#  |4|Maestre|Mecanico|
#  |5|
#  |6|
#
#  |0|
#  |1|Niñas|
#  |2|Niños|3ra Edad|
#  |3|Mujeres|Hombres|
#  |4|Maestre|Mecanico|
#  |5|
#  |6|
#
#  |0|
#  |1|Niñas|
#  |2|Niños|3ra Edad|
#  |3|Mujeres|Hombres|
#  |4|Maestre|Mecanico|Vigia|
#  |5|
#  |6|
#
#  |0|
#  |1|Niñas|
#  |2|Niños|3ra Edad|
#  |3|Mujeres|Hombres|
#  |4|Maestre|Mecanico|Vigia|
#  |5|Capitan|
#  |6|
#
#  |0|
#  |1|Niñas|
#  |2|Niños|3ra Edad|
#  |3|Mujeres|Hombres|
#  |4|Maestre|Mecanico|Vigia|Timonel|
#  |5|Capitan|
#  |6|
#
#
# Abandonando el barco
#
#  |0|
#  |1|
# ...
